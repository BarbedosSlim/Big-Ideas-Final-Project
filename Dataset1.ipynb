# %% [markdown]
# # Percentage of Buildings in Good Condition
# #### Cole Caron

# %% [markdown]
# Buildings in good condition are less prone to damage during an earthquake, so being in a neighborhood with a higher ratio of buildings in good condition would be ideal in the event of an earthquake.

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
buildings = pd.read_csv("Built Environment Conditions.csv")
buildings
# Out:
#            Neighborhood  Sector # Population (2010) Land Area (acres)  \
# 0      Allegheny Center         3               933             134.4
# 1        Allegheny West         3               462              90.2
# 2             Allentown         6             2,500             188.8
# 3             Arlington         7             1,869             300.8
# 4     Arlington Heights         7               244              84.5
# ..                  ...       ...               ...               ...
# 85  Upper Lawrenceville        13             2,669             259.2
# 86             West End         4               254             128.0
# 87         West Oakland        14             2,604             137.6
# 88             Westwood         4             3,066             442.9
# 89              Windgap         4             1,369             265.6
#
#    Approx. Total # Parcels (2010) Approx. Total # Taxable Parcels (2010)  \
# 0                              67                                     26
# 1                             282                                    234
# 2                           1,550                                  1,402
# 3                           1,049                                    950
# 4                              10                                      7
# ..                            ...                                    ...
# 85                          1,463                                  1,365
# 86                            384                                    295
# 87                            801                                    540
# 88                          1,581                                  1,487
# 89                            716                                    668
#
#    Approx. # of Structures (2010) Approx. # Unoccupied Parcels (2010)  \
# 0                              58                                  15
# 1                             176                                  49
# 2                           1,283                                 334
# 3                           1,034                                 198
# 4                              13                                   4
# ..                            ...                                 ...
# 85                            901                                 187
# 86                            186                                 156
# 87                            140                                  82
# 88                          1,391                                 278
# 89                            749                                  92
#
#    % Good / Excellent Condition Buildings (2009)  \
# 0                                            NaN
# 1                                          72.0%
# 2                                           2.5%
# 3                                           0.3%
# 4                                            NaN
# ..                                           ...
# 85                                          6.9%
# 86                                          1.0%
# 87                                          0.6%
# 88                                         22.7%
# 89                                         14.8%
#
#    % Average Condition Buildings (2009)  ...  \
# 0                                   NaN  ...
# 1                                 22.3%  ...
# 2                                 86.9%  ...
# 3                                 97.6%  ...
# 4                                   NaN  ...
# ..                                  ...  ...
# 85                                85.6%  ...
# 86                                92.2%  ...
# 87                                89.7%  ...
# 88                                76.4%  ...
# 89                                84.4%  ...
#
#    $ Residential Bldg. Permits (2010)  # Commercial Bldg. Permits (2010)  \
# 0                                  $0                                  6
# 1                             $30,784                                  6
# 2                            $349,708                                  1
# 3                            $159,496                                  1
# 4                                  $0                                  0
# ..                                ...                                ...
# 85                           $304,522                                 11
# 86                            $14,754                                  0
# 87                            $63,786                                 24
# 88                           $415,770                                  1
# 89                           $138,050                                  0
#
#    $ Commercial Bldg. Permits (2010)  # Code Violations (2010)  \
# 0                         $6,314,000                         0
# 1                           $795,300                         3
# 2                           $350,000                       175
# 3                            $50,000                       130
# 4                                 $0                         0
# ..                               ...                       ...
# 85                        $2,419,600                        56
# 86                                $0                        10
# 87                        $9,080,856                        50
# 88                           $19,500                        25
# 89                                $0                        27
#
#    % of all Bldgs. w/ Code Violations (2010)  # Condemned Structures (2010)  \
# 0                                       0.0%                              0
# 1                                       1.7%                              1
# 2                                      13.6%                             30
# 3                                      12.6%                             10
# 4                                       0.0%                              0
# ..                                       ...                            ...
# 85                                      6.2%                             18
# 86                                      5.4%                              1
# 87                                     35.7%                              1
# 88                                      1.8%                              4
# 89                                      3.6%                              1
#
#    % of all Bldgs. Condemned (2010)  # Demolitions (2010)  \
# 0                              0.0%                     0
# 1                              0.6%                     0
# 2                              2.3%                    16
# 3                              1.0%                     7
# 4                              0.0%                     0
# ..                              ...                   ...
# 85                             2.0%                     6
# 86                             0.5%                     3
# 87                             0.7%                     0
# 88                             0.3%                     1
# 89                             0.1%                     0
#
#    # Tax Delinquent Prop. (2+ yrs.) (2010)  \
# 0                                        0
# 1                                        3
# 2                                      287
# 3                                      142
# 4                                        3
# ..                                     ...
# 85                                     105
# 86                                      40
# 87                                      92
# 88                                      65
# 89                                      33
#
#     % of Taxable Prop. Delinquent (2010)
# 0                                   0.0%
# 1                                   1.3%
# 2                                  20.5%
# 3                                  14.9%
# 4                                  42.9%
# ..                                   ...
# 85                                  7.7%
# 86                                 13.6%
# 87                                 17.0%
# 88                                  4.4%
# 89                                  4.9%
#
# [90 rows x 22 columns]

# %%
myList = dict()
for x in range(len(buildings)):
    value = buildings.loc[x]["Neighborhood"]
    myList[value] = (buildings.loc[x]["% Good / Excellent Condition Buildings (2009)"])
myList
# Out:
# {'Allegheny Center': nan,
#  'Allegheny West': '72.0%',
#  'Allentown': '2.5%',
#  'Arlington': '0.3%',
#  'Arlington Heights': nan,
#  'Banksville': '7.0%',
#  'Bedford Dwellings': nan,
#  'Beechview': '1.3%',
#  'Beltzhoover': '1.7%',
#  'Bloomfield': '9.7%',
#  'Bluff': '22.2%',
#  'Bon Air': '2.9%',
#  'Brighton Heights': '9.5%',
#  'Brookline': '0.2%',
#  'California-Kirkbride': '2.9%',
#  'Carrick': '0.2%',
#  'Central Business District': '32.0%',
#  'Central Lawrenceville': '18.7%',
#  'Central Northside': '42.9%',
#  'Central Oakland': '5.3%',
#  'Chartiers City': '7.8%',
#  'Chateau': nan,
#  'Crafton Heights': '6.7%',
#  'Crawford-Roberts': '27.6%',
#  'Duquesne Heights': '6.0%',
#  'East Allegheny': '20.9%',
#  'East Carnegie': '3.1%',
#  'East Hills': '5.7%',
#  'East Liberty': '21.2%',
#  'Elliott': '0.6%',
#  'Esplen': '0.9%',
#  'Fairywood': nan,
#  'Fineview': '6.7%',
#  'Friendship': '17.8%',
#  'Garfield': '5.0%',
#  'Glen Hazel': nan,
#  'Greenfield': '1.0%',
#  'Hays': '1.6%',
#  'Hazelwood': '0.7%',
#  'Highland Park': '13.6%',
#  'Homewood North': '1.2%',
#  'Homewood South': '9.8%',
#  'Homewood West': '2.4%',
#  'Knoxville': '1.7%',
#  'Larimer': '4.9%',
#  'Lincoln Place': '2.1%',
#  'Lincoln-Lemington-Belmar': '3.0%',
#  'Lower Lawrenceville': '6.6%',
#  'Manchester': '21.6%',
#  'Marshall-Shadeland': '7.2%',
#  'Middle Hill': '9.3%',
#  'Morningside': '2.3%',
#  'Mount Washington': '11.9%',
#  'Mt. Oliver': '0.0%',
#  'New Homestead': '13.5%',
#  'North Oakland': '15.4%',
#  'North Shore': '80.0%',
#  'Northview Heights': nan,
#  'Oakwood': '20.3%',
#  'Overbrook': '2.4%',
#  'Perry North': '1.7%',
#  'Perry South': '5.0%',
#  'Point Breeze': '6.9%',
#  'Point Breeze North': '5.7%',
#  'Polish Hill': '5.2%',
#  'Regent Square': '16.4%',
#  'Ridgemont': '9.8%',
#  'Shadyside': '13.9%',
#  'Sheraden': '1.1%',
#  'South Oakland': '0.8%',
#  'South Shore': nan,
#  'South Side Flats': '12.7%',
#  'South Side Slopes': '1.8%',
#  'Spring Garden': '3.9%',
#  'Spring Hill-City View': '4.8%',
#  'Squirrel Hill North': '17.6%',
#  'Squirrel Hill South': '5.6%',
#  'St. Clair': nan,
#  'Stanton Heights': '9.3%',
#  'Strip District': '12.7%',
#  'Summer Hill': '8.4%',
#  'Swisshelm Park': '11.7%',
#  'Terrace Village': nan,
#  'Troy Hill': '0.0%',
#  'Upper Hill': '5.0%',
#  'Upper Lawrenceville': '6.9%',
#  'West End': '1.0%',
#  'West Oakland': '0.6%',
#  'Westwood': '22.7%',
#  'Windgap': '14.8%'}

# %%
BuildingData = RatioSeries.sort_values(ascending=False).head(30)
plt.bar(BuildingData.index, BuildingData.values)
plt.title("Highest Number Buildings in Good Condition Percentage")
plt.ylabel('Percentage')  # Rotate x-axis labels if needed
plt.xticks(rotation=90)
fig = plt.gcf()
fig.set_size_inches(13,7)
plt.show()

# %% [markdown]
# ## Top 5 Highest Percentages for Number of Buildings in Good Condition:
# 1. North Shore
# 2. Allegheny West
# 3. Central Northside
# 4. Central Business District
# 5. Crawford-Roberts
